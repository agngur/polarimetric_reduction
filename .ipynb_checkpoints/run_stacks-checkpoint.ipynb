# %%
# %load_ext autoreload
# %autoreload 2
from stacks import prepare_stack
import datetime as dt
 

prepare_stack(main_dir='/home/pi/DATA/astro/dane_malykluk/',
              save_dir='/home/pi/DATA/astro/dane_malykluk/stacked_fields/',
              hdr_keys='/home/pi/DATA/astro/dane_malykluk/polarimetric_reduction/hdr_key.txt',
              start_date=dt.datetime(2017, 6, 9),
              end_date=dt.datetime(2020, 6, 10), exps=[5], astrometry=False)
# Out:
# [autoreload of stacks failed: Traceback (most recent call last):
#   File "/home/pi/Programs/anaconda2/envs/astro/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/pi/DATA/astro/dane_malykluk/polarimetric_reduction/stacks.py", line 176
#     """
#       ^
# SyntaxError: EOF while scanning triple-quoted string literal
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sextractor ,/home/pi/DATA/astro/dane_malykluk/2017-08-30/2457995_224137+445841_033_P1-5_red.fit -c .pysex.sex -CATALOG_NAME .pysex.cat -FILTER Y -VERBOSE_TYPE QUIET -PARAMETERS_NAME .pysex.param -SEEING_FWHM 2.0 -ANALYSIS_THRESH 10.0 -DETECT_MINAREA 10 -FILTER_NAME .pysex.conv -DETECT_THRESH 10.0 -STARNNW_NAME .pysex.nnw -PIXEL_SCALE 1.0
# X_IMAGE   Y_IMAGE  FLUX_AUTO FWHM_IMAGE FLAGS ELONGATION NUMBER EXT_NUMBER
#   pix       pix        ct       pix
# ...

# %%
import glob

# %%
main_dir='/home/agngur/Dokumenty/survey/2017-01-07/'
images = glob.glob(main_dir+'*_red.fit')
images
# Out:
# []
